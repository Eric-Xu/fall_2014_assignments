# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from IPython.display import Image
import statsmodels.api as sm

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (10, 5)

# %%
# data = pd.read_csv("africa_ph.csv", header=0) # from outside virtual box
data = pd.read_csv("/ga_fall_2014/fall_2014_assignments/dataexplor02/exu/africa_ph.csv", header=0) # from inside virtual box

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 736 entries, 0 to 735
# Data columns (total 12 columns):
# Unnamed: 0    736 non-null int64
# PIDN          736 non-null object
# pH            736 non-null float64
# ELEV          736 non-null float64
# REF2          736 non-null float64
# BSAN          736 non-null float64
# LSTN          736 non-null float64
# Infrared01    736 non-null float64
# Infrared02    736 non-null float64
# Infrared03    736 non-null float64
# Infrared04    736 non-null float64
# Infrared05    736 non-null float64
# dtypes: float64(10), int64(1), object(1)

# %%
data.describe()
# Out:
#        Unnamed: 0          pH        ELEV        REF2        BSAN        LSTN  \
# count  736.000000  736.000000  736.000000  736.000000  736.000000  736.000000
# mean   399.500000    0.019585    0.403813   -0.429374   -0.563376   -0.011037
# std    212.609188    0.964509    1.607167    0.329725    0.209979    0.958168
# min     32.000000   -1.886946   -1.326726   -1.642857   -1.007246   -2.720276
# 25%    215.750000   -0.717841   -1.050557   -0.657699   -0.695652   -0.448294
# 50%    399.500000   -0.137964   -0.166370   -0.442486   -0.586957    0.089564
# 75%    583.250000    0.455941    1.365367   -0.205937   -0.449275    0.750153
# max    767.000000    2.480832    4.891537    0.335807    0.217391    1.519218
#
#        Infrared01  Infrared02  Infrared03  Infrared04  Infrared05
# count  736.000000  736.000000  736.000000  736.000000  736.000000
# mean     0.307313    0.070904    1.315295    1.776879    1.494852
# std      0.092668    0.041800    0.253520    0.175960    0.159071
# min      0.044781    0.009202    0.367167    1.295110    1.132220
# 25%      0.249050    0.041492    1.166361    1.675233    1.382195
# 50%      0.294500    0.059636    1.340995    1.742140    1.506285
# 75%      0.356444    0.090415    1.493126    1.848032    1.609793
# max      0.761519    0.246435    1.888528    2.569190    1.999830

# %%
data.head()
# Out:
#    Unnamed: 0      PIDN        pH      ELEV      REF2      BSAN      LSTN  \
# 0          32  d9u06tdU -0.044436  0.904900 -0.352505 -0.710145 -0.371001
# 1          33  qsQFu3ef -0.455961  0.904900 -0.352505 -0.710145 -0.371001
# 2          34  C4kj5IMN -0.549490  0.971715 -0.352505 -0.702899 -0.399312
# 3          35  p1SCgsM8 -0.951662  0.971715 -0.352505 -0.702899 -0.399312
# 4          36  UqyLWYTl -0.427903  0.929399 -0.506494 -0.695652 -0.543779
#
#    Infrared01  Infrared02  Infrared03  Infrared04  Infrared05
# 0    0.378298    0.056228    1.349732     1.81377     1.65483
# 1    0.374321    0.072229    1.459569     1.78552     1.62982
# 2    0.390773    0.048228    1.555917     1.73194     1.63317
# 3    0.385719    0.047679    1.662981     1.68115     1.69190
# 4    0.411471    0.043002    1.522019     1.71672     1.68936

# %%
plt.plot(data.Infrared01, data.pH, 'o', alpha=0.4)
plt.ylabel('soil pH')

# %%
plt.plot(data.Infrared02, data.pH, 'o', alpha=0.4, color='green')
plt.ylabel('soil pH')

# %%
plt.plot(data.Infrared03, data.pH, 'o', alpha=0.4, color='yellow')
plt.ylabel('soil pH')

# %%
plt.plot(data.Infrared04, data.pH, 'o', alpha=0.4, color='orange')
plt.ylabel('soil pH')

# %%
plt.plot(data.Infrared05, data.pH, 'o', alpha=0.4, color='red')
plt.ylabel('soil pH')

# %% [markdown]
# ### Regression modeling with Scikit Learn

# %%
x = data.Infrared02 # predictor
x.shape
# Out:
# (736,)

# %%
y = data.pH # response
y.shape
# Out:
# (736,)

# %%
new_x = x.reshape(736, 1)
new_y = y.reshape(736, 1)

# %%
model = LinearRegression(fit_intercept=True)
model.fit(new_x, new_y)
print ("Model coefficient: %.5f, and intercept: %.5f" % (model.coef_, model.intercept_))
# Out:
# Model coefficient: 12.84629, and intercept: -0.89127

# %%
# pick 100 hundred points equally spaced from the min to the max
x_test = np.linspace(data.Infrared02.min(), data.Infrared02.max(), 100).reshape(100,1)
y_hat = model.predict(x_test)

# %%
plt.plot(data.Infrared02, data.pH, 'o', alpha=0.5, color='green')
plt.plot(x_test, y_hat)
plt.ylabel('soil pH')

# %%
# y = model.coef_(x) + model.intercept_
test_pH = 12.84629 * 0.04079 - 0.89127

# %%
test_pH
# Out:
# -0.3672698309

# %% [markdown]
# ### Not sure how to calculate p-value with Scikit so going to redo prediction with Statsmodel instead.

# %%
sm_x = data.Infrared02 # predictor
sm_y = data.pH # response
sm_x = sm.add_constant(sm_x) # add a constant term to the predictor
sm_x.head(3)
# Out:
#    const  Infrared02
# 0      1    0.056228
# 1      1    0.072229
# 2      1    0.048228

# %%
sm_mod = sm.OLS(sm_y, sm_x) # describe model
sm_res = sm_mod.fit() # fit model
print sm_res.summary() # summarize model
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     pH   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     329.7
# Date:                Sat, 04 Oct 2014   Prob (F-statistic):           3.91e-61
# Time:                        23:51:48   Log-Likelihood:                -880.72
# No. Observations:                 736   AIC:                             1765.
# Df Residuals:                     734   BIC:                             1775.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         -0.8913      0.058    -15.308      0.000        -1.006    -0.777
# Infrared02    12.8463      0.708     18.157      0.000        11.457    14.235
# ==============================================================================
# Omnibus:                        9.686   Durbin-Watson:                   0.667
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.925
# Skew:                           0.276   Prob(JB):                      0.00699
# Kurtosis:                       2.860   Cond. No.                         24.1
# ==============================================================================

# %%
# same as sklearn's model coefficient: 12.84629, and intercept: -0.89127
sm_res.params # extract parameter estimates
# Out:
# const         -0.891269
# Infrared02    12.846289
# dtype: float64

# %%
sm_res.rsquared
# Out:
# 0.30994731310631118

# %%
# pick 100 hundred points equally spaced from the min to the max
sm_x_test = np.linspace(data.Infrared02.min(), data.Infrared02.max(), 100)
sm_x_test = sm.add_constant(sm_x_test)
sm_y_hat = est.predict(sm_x_test)

# %%
plt.plot(sm_x_test[:,1], sm_y_hat, color='purple')
plt.plot(data.Infrared02, data.pH, 'o', alpha=.5, color='green')
plt.ylabel('soil pH')

# %% [markdown]
# ## Create the submission file

# %%
# PIDN,      Ca,  P,  pH,  SOC,  Sand
# 09gt9UK5,  0,   0,  0,   0,    0

# %%
test_file = pd.read_csv("/ga_fall_2014/fall_2014_assignments/dataexplor02/exu/kaggle_data/sorted_test.csv", header=0)

# %% [markdown]
# How to get p-value using scikit?
# Faster way to predict Y using linear regression line equation?
